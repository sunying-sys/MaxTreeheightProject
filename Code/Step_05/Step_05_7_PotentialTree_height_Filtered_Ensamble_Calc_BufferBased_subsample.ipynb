# %% [markdown]
# # Tree height (Filtered) maping ensemble calculation in GEE

# %%
# import the libraries
import ee
import pandas as pd
import os
import numpy as np
from termcolor import colored # this is allocate colour and fonts type for the print title and text

# %%
# initialize the earth engine API
ee.Initialize(project='ee-sun520ying')

# %% [markdown]
# ## load all the Max tree height images into a multiband image

# %%
# load the images for the 50 ensemble models
# define an empty image
firstImage = ee.Image('users/sun520ying/TreeStructureProject/PredictedMaps/Predicted_PotentialMax_TreeHeight_Filtered_BufferBased_20260407_Mean_Map_with_Seed_0').rename('Model_0')
modelList = np.arange(1, 50, 1).tolist()
for ml in modelList:
    perModelImage = ee.Image('users/sun520ying/TreeStructureProject/PredictedMaps/Predicted_PotentialMax_TreeHeight_Filtered_BufferBased_20260407_Mean_Map_with_Seed_'+str(ml)).rename('Model_'+str(ml))
    firstImage = firstImage.addBands(perModelImage)

print(colored('The band names are:', 'blue', attrs=['bold']),firstImage.bandNames().getInfo())
# Out:
# The band names are: ['Model_0', 'Model_1', 'Model_2', 'Model_3', 'Model_4', 'Model_5', 'Model_6', 'Model_7', 'Model_8', 'Model_9', 'Model_10', 'Model_11', 'Model_12', 'Model_13', 'Model_14', 'Model_15', 'Model_16', 'Model_17', 'Model_18', 'Model_19', 'Model_20', 'Model_21', 'Model_22', 'Model_23', 'Model_24', 'Model_25', 'Model_26', 'Model_27', 'Model_28', 'Model_29', 'Model_30', 'Model_31', 'Model_32', 'Model_33', 'Model_34', 'Model_35', 'Model_36', 'Model_37', 'Model_38', 'Model_39', 'Model_40', 'Model_41', 'Model_42', 'Model_43', 'Model_44', 'Model_45', 'Model_46', 'Model_47', 'Model_48', 'Model_49']

# %%
# define the boundary geography reference
unboundedGeo = ee.Geometry.Polygon([-180, 88, 0, 88, 180, 88, 180, -88, 0, -88, -180, -88], None, False)

# %% [markdown]
# ## Calculate the Mean and variation coefficient maps of Max tree height

# %%
# calculate the mean and variation images
meanImage = firstImage.reduce(ee.Reducer.mean())
variImage = firstImage.reduce(ee.Reducer.stdDev()).divide(meanImage)
#95% quantile range
quantileImage = firstImage.reduce(ee.Reducer.percentile([2.5,97.5],['lower','upper']))

# %% [markdown]
# ## Export Mean and variation coefficient maps of max tree height to Asset

# %%
# add those two images into the GEE assets
meanExport = ee.batch.Export.image.toAsset(image = meanImage,
                                           description = '20260407_TreeMaxHeight_Filtered_Ensemble_Map_Mean_To_Asset',
                                           assetId = 'users/sun520ying/TreeStructureProject/EnsembleMaps/PotentialTree_Max_Height_Filtered_20260407_Ensemble_Mean_BufferBased',
                                           region = unboundedGeo,
                                           crs = 'EPSG:4326',
                                           crsTransform = [0.008333333333333333,0,-180,0,-0.008333333333333333,90],
                                           maxPixels = 1e13)


# start the export task
meanExport.start()
# show the task status
meanExport.status()
# Out:
# {'state': 'READY',
#  'description': '20260407_TreeMaxHeight_Filtered_Ensemble_Map_Mean_To_Asset',
#  'priority': 100,
#  'creation_timestamp_ms': 1776180413310,
#  'update_timestamp_ms': 1776180413310,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': 'UU2R23SRRDRNWZOE5FVHQZN4',
#  'name': 'projects/ee-sun520ying/operations/UU2R23SRRDRNWZOE5FVHQZN4'}

# %%
variExport = ee.batch.Export.image.toAsset(image = variImage,
                                           description = '20250923_TreeMaxHeight_Filtered_Ensemble_Map_Vari_To_Asset',
                                           assetId = 'users/sun520ying/TreeStructureProject/EnsembleMaps/PotentialTree_Max_Height_Filtered_20260407_Ensemble_Vari_BufferBased',
                                           region = unboundedGeo,
                                           crs = 'EPSG:4326',
                                           crsTransform = [0.008333333333333333,0,-180,0,-0.008333333333333333,90],
                                           maxPixels = 1e13)

# start the export task
variExport.start()
# show the task status
variExport.status()
# Out:
# {'state': 'READY',
#  'description': '20250923_TreeMaxHeight_Filtered_Ensemble_Map_Vari_To_Asset',
#  'priority': 100,
#  'creation_timestamp_ms': 1776180414246,
#  'update_timestamp_ms': 1776180414246,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': 'G5RJLQL5ONVDFURBITOFTPEG',
#  'name': 'projects/ee-sun520ying/operations/G5RJLQL5ONVDFURBITOFTPEG'}

# %%
quantileExport = ee.batch.Export.image.toAsset(image = quantileImage,
                                           description = '20250923_TreeMaxHeight_Filtered_Ensemble_Map_Quantile_To_Asset',
                                           assetId = 'users/sun520ying/TreeStructureProject/EnsembleMaps/PotentialTree_Max_Height_Filtered_20260407_Ensemble_Quantile_BufferBased',
                                           region = unboundedGeo,
                                           crs = 'EPSG:4326',
                                           crsTransform = [0.008333333333333333,0,-180,0,-0.008333333333333333,90],
                                           maxPixels = 1e13)

# start the export task
quantileExport.start()
# show the task status
quantileExport.status()
# Out:
# {'state': 'READY',
#  'description': '20250923_TreeMaxHeight_Filtered_Ensemble_Map_Quantile_To_Asset',
#  'priority': 100,
#  'creation_timestamp_ms': 1776180415389,
#  'update_timestamp_ms': 1776180415389,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': '3GD3NRZCLW53YPGVFZSGE6YV',
#  'name': 'projects/ee-sun520ying/operations/3GD3NRZCLW53YPGVFZSGE6YV'}
